# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\sidharth\Desktop\happycars\CarModels.csv')
df.head()
# Out:
#    CarID       Brand   Model    Type  Price  Margin
# 0      1       Volvo     S12   Sedan  24000    0.08
# 1      2       Volvo     S14  Estate  28000    0.09
# 2      3       Volvo     X14     SUV  35000    0.09
# 3      4  VolksWagen  passat   Sedan  19000    0.06
# 4      5  VolksWagen  passat  Estate  22000    0.06

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=df,x='Brand')
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=df,x='Model')
# Out:
# <AxesSubplot:xlabel='Model', ylabel='Count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.displot(data=df,x='Type')

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=df["Price"])

# %%
sns.set_theme(style="whitegrid")
ax = sns.violinplot(x=df["Margin"])
