# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("/Users/HP/Downloads/Non Customers.csv")
data.head()
# Out:
#    CustomerID Title FirstName MiddleName LastName            BirthDate  \
# 0       27489   NaN     Haley        NaN     Hall  1951-08-14 00:00:00
# 1       20417   NaN     Bruce          P  Vazquez  1950-02-11 00:00:00
# 2       20106   NaN     Amber        NaN     Hall  1957-09-21 00:00:00
# 3       28475   NaN     Bruce        NaN    Ramos  1941-06-11 00:00:00
# 4       19528   NaN    Bailey          C     Hall  1967-05-14 00:00:00
#
#   MaritalStatus YearlyIncome Gender  TotalChildren  NumberChildrenAtHome  \
# 0             S      0-25000      F              2                     1
# 1             M  25001-50000      M              3                     0
# 2             M  25001-50000      F              2                     0
# 3             S      0-25000      M              2                     0
# 4             S  25001-50000      F              0                     0
#
#              Education      Occupation  HomeOwner CommuteDistance
# 0  Partial High School        Clerical       True      5-10 Miles
# 1      Partial College        Clerical      False      5-10 Miles
# 2          High School  Skilled Manual      False       0-1 Miles
# 3      Partial College          Manual      False       2-5 Miles
# 4      Partial College  Skilled Manual      False       0-1 Miles

# %%
data.describe().transpose()
# Out:
#                        count          mean          std      min      25%  \
# CustomerID            4246.0  20164.814414  5397.956824  11001.0  15349.5
# TotalChildren         4246.0      1.622468     1.500829      0.0      0.0
# NumberChildrenAtHome  4246.0      0.745878     1.264800      0.0      0.0
#
#                           50%       75%      max
# CustomerID            20152.5  24966.25  29477.0
# TotalChildren             1.0      3.00      5.0
# NumberChildrenAtHome      0.0      1.00      5.0

# %%
data.isnull().sum()
# Out:
# CustomerID                 0
# Title                   4216
# FirstName                  0
# MiddleName              1842
# LastName                   0
# BirthDate                  0
# MaritalStatus              0
# YearlyIncome               0
# Gender                     0
# TotalChildren              0
# NumberChildrenAtHome       0
# Education                  0
# Occupation                 0
# HomeOwner                  0
# CommuteDistance            0
# dtype: int64

# %%
data.drop(['CustomerID','Title','FirstName','MiddleName','LastName'],'columns',inplace=True)
data.head()
# Out:
#              BirthDate MaritalStatus YearlyIncome Gender  TotalChildren  \
# 0  1951-08-14 00:00:00             S      0-25000      F              2
# 1  1950-02-11 00:00:00             M  25001-50000      M              3
# 2  1957-09-21 00:00:00             M  25001-50000      F              2
# 3  1941-06-11 00:00:00             S      0-25000      M              2
# 4  1967-05-14 00:00:00             S  25001-50000      F              0
#
#    NumberChildrenAtHome            Education      Occupation  HomeOwner  \
# 0                     1  Partial High School        Clerical       True
# 1                     0      Partial College        Clerical      False
# 2                     0          High School  Skilled Manual      False
# 3                     0      Partial College          Manual      False
# 4                     0      Partial College  Skilled Manual      False
#
#   CommuteDistance
# 0      5-10 Miles
# 1      5-10 Miles
# 2       0-1 Miles
# 3       2-5 Miles
# 4       0-1 Miles

# %%
data['BirthDate']=pd.to_datetime(data['BirthDate'])
data
# Out:
#       BirthDate MaritalStatus YearlyIncome Gender  TotalChildren  \
# 0    1951-08-14             S      0-25000      F              2
# 1    1950-02-11             M  25001-50000      M              3
# 2    1957-09-21             M  25001-50000      F              2
# 3    1941-06-11             S      0-25000      M              2
# 4    1967-05-14             S  25001-50000      F              0
# ...         ...           ...          ...    ...            ...
# 4241 1958-09-25             M  25001-50000      F              1
# 4242 1958-03-29             M  50001-75000      F              1
# 4243 1959-05-14             M  50001-75000      F              1
# 4244 1973-03-24             S  25001-50000      F              0
# 4245 1955-03-25             M  25001-50000      F              1
#
#       NumberChildrenAtHome            Education      Occupation  HomeOwner  \
# 0                        1  Partial High School        Clerical       True
# 1                        0      Partial College        Clerical      False
# 2                        0          High School  Skilled Manual      False
# 3                        0      Partial College          Manual      False
# 4                        0      Partial College  Skilled Manual      False
# ...                    ...                  ...             ...        ...
# 4241                     0      Partial College        Clerical       True
# 4242                     0           Bachelors     Professional       True
# 4243                     0      Partial College  Skilled Manual       True
# 4244                     0          High School          Manual       True
# 4245                     0      Partial College        Clerical       True
#
#      CommuteDistance
# 0         5-10 Miles
# 1         5-10 Miles
# 2          0-1 Miles
# 3          2-5 Miles
# 4          0-1 Miles
# ...              ...
# 4241       1-2 Miles
# 4242       2-5 Miles
# 4243       2-5 Miles
# 4244       2-5 Miles
# 4245       1-2 Miles
#
# [4246 rows x 10 columns]

# %%
data['BirthDate'].describe()
# Out:
# <ipython-input-7-04d4a8b8a122>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data['BirthDate'].describe()
# count                    4246
# unique                   3402
# top       1968-04-17 00:00:00
# freq                        5
# first     1912-08-14 00:00:00
# last      1980-12-24 00:00:00
# Name: BirthDate, dtype: object

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.displot(data=data,x='BirthDate',kde=True)

# %%
data['MaritalStatus'].describe()
# Out:
# count     4246
# unique       2
# top          S
# freq      2189
# Name: MaritalStatus, dtype: object

# %%
sns.histplot(data=data,x='MaritalStatus')
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='Count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='TotalChildren',data=data)
# Out:
# <AxesSubplot:xlabel='TotalChildren', ylabel='count'>

# %%
data['Gender'].describe()
# Out:
# count     4246
# unique       2
# top          M
# freq      2140
# Name: Gender, dtype: object

# %%
sns.histplot(data=data,x='Gender')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %%
data['Education'].describe()
# Out:
# count                4246
# unique                  5
# top       Partial College
# freq                 1628
# Name: Education, dtype: object

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='Education')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Count'>

# %%
data['Occupation'].describe()
# Out:
# count             4246
# unique               5
# top       Professional
# freq              1144
# Name: Occupation, dtype: object

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='Occupation')
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='Count'>

# %%
data['HomeOwner'].describe()
# Out:
# count     4246
# unique       2
# top       True
# freq      2670
# Name: HomeOwner, dtype: object

# %%
sns.histplot(data=data,x='HomeOwner')
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <AxesSubplot:xlabel='HomeOwner', ylabel='Count'>

# %%
data['CommuteDistance'].describe()
# Out:
# count          4246
# unique            5
# top       0-1 Miles
# freq           1204
# Name: CommuteDistance, dtype: object

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='CommuteDistance')
# Out:
# <AxesSubplot:xlabel='CommuteDistance', ylabel='Count'>

# %%
data['YearlyIncome'].describe()
# Out:
# count            4246
# unique              5
# top       25001-50000
# freq             1459
# Name: YearlyIncome, dtype: object

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.histplot(data=data,x='YearlyIncome')
# Out:
# <AxesSubplot:xlabel='YearlyIncome', ylabel='Count'>

# %%
data['NumberChildrenAtHome'].describe()
# Out:
# count    4246.000000
# mean        0.745878
# std         1.264800
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         5.000000
# Name: NumberChildrenAtHome, dtype: float64

# %%
sns.boxplot(data=data,x='NumberChildrenAtHome')
# Out:
# <AxesSubplot:xlabel='NumberChildrenAtHome'>

# %%
data['TotalChildren'].describe()
# Out:
# count    4246.000000
# mean        1.622468
# std         1.500829
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         3.000000
# max         5.000000
# Name: TotalChildren, dtype: float64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(x='TotalChildren',data=data)
# Out:
# <AxesSubplot:xlabel='TotalChildren'>
